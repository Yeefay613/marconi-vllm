# %%
from plotting.prefix_cache_strategy_plots import *

df_p25 = load_prefix_cache_results("results/sharegpt_sps=0.25_marconi_vs_vllm.csv")
df_p5 = load_prefix_cache_results("results/sharegpt_sps=0.5_marconi_vs_vllm.csv")
df_1 = load_prefix_cache_results("results/sharegpt_sps=1_marconi_vs_vllm.csv")
df_2 = load_prefix_cache_results("results/sharegpt_sps=2_marconi_vs_vllm.csv")
df_5 = load_prefix_cache_results("results/sharegpt_sps=5_marconi_vs_vllm.csv")
df_10 = load_prefix_cache_results("results/sharegpt_sps=10_marconi_vs_vllm.csv")

# %%
# Compare Marconi vs vLLM+ first
fig, ax = plot_hit_rate_by_capacity(df_p25)

# %%
fig, ax = plot_hit_rate_by_capacity(df_p5)

# %%
fig, ax = plot_hit_rate_by_capacity(df_1)

# %%
fig, ax = plot_hit_rate_by_capacity(df_2)

# %%
fig, ax = plot_hit_rate_by_capacity(df_5)

# %%
fig, ax = plot_hit_rate_by_capacity(df_10)

# %%
# Relative Marconi gain over vLLM+
fig, ax = plot_marconi_vs_vllm_gain(df)

# %%
# Add the simple hybrid prefix cache later, using kv_cache_fraction=0.5
fig, ax = plot_hit_rate_by_capacity(df, include_simple=True, simple_kv_fraction=0.5)

# %%
# Simple hybrid prefix cache sensitivity to KV fraction at one capacity
fig, ax = plot_hit_rate_by_kv_fraction(df, capacity_gb=5)

# %%
# Optional memory usage plot
fig, ax = plot_cache_memory_usage(df, include_simple=True, simple_kv_fraction=0.5)
